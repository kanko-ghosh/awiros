# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics==8.0.0

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/Helmet/data.yaml epochs=70 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 240MB/s]
#
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Helmet/data.yaml
# Out:
# 2023-10-04 08:04:59.504810: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-04 08:05:00.992480: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Helmet/archive/val/labels.cache... 152 images, 10 backgrounds, 0 corrupt: 100% 162/162 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11/11 [00:07<00:00,  1.50it/s]
#                    all        162        282      0.744      0.701      0.736      0.441
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Helmet/archive/test/images
# Out:
# 2023-10-04 08:06:34.423469: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-04 08:06:35.411440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# image 1/152 /content/drive/MyDrive/Helmet/archive/test/images/BikesHelmets105.png: 640x640 1 With, 37.1ms
# image 2/152 /content/drive/MyDrive/Helmet/archive/test/images/BikesHelmets106.png: 640x640 2 Withs, 37.2ms
# image 3/152 /content/drive/MyDrive/Helmet/archive/test/images/BikesHelmets114.png: 640x640 7 Withs, 37.0ms
# ...

# %%
# %cp /content/yolov8m.pt /content/drive/MyDrive/Helmet/Res2/yolov8m.pt

# %%
from IPython.display import Image
Image("/content/runs/detect/predict/BikesHelmets2.png")
